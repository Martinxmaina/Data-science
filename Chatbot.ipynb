# %% [markdown]
# <a href="https://colab.research.google.com/github/Martinxmaina/Data-science/blob/main/Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mistralai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.6/271.6 kB 4.1 MB/s eta 0:00:00
# ...

# %%
from mistralai import Mistral # Import the Mistral class instead of 'mistralai'

# %%
user= Mistral(api_key="owbpM7d3TUu5PjIxYU7GajnUCh6k33vg")

# %%
userrole= "User"

# %%
response = user.chat(  # Use 'chat' method instead of 'create_chat_completion'
    model="Mistral-7B-Instruct",
    messages=[
        {"role": userrole, "content": "your prompt here"}
    ]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-3e744bbee6f7> in <cell line: 0>()
# ----> 1 response = user.chat(  # Use 'chat' method instead of 'create_chat_completion'
#       2     model="Mistral-7B-Instruct",
#       3     messages=[
#       4         {"role": userrole, "content": "your prompt here"}
#       5     ]
#
# TypeError: 'Chat' object is not callable

# %%
export MISTRAL_API_KEY=("owbpM7d3TUu5PjIxYU7GajnUCh6k33vg")
# Out:
#   File "<ipython-input-30-24dd930938f5>", line 1
#     export MISTRAL_API_KEY=("owbpM7d3TUu5PjIxYU7GajnUCh6k33vg")
#            ^
# SyntaxError: invalid syntax

# %%
mistralmodel= "Model-7B-Instruct"

# %%
try:
    mistral = Mistral()
except Exception as e:
    print(f"Failed to create Mistral instance: {e}")
    exit(1)

# %%
# Out:
#   File "<ipython-input-26-ff945291044e>", line 23
#     print(f"Error during chat call: {e}"))
#                                          ^
# SyntaxError: unmatched ')'

# %%
from transformers import pipeline

# Load a pre-trained chat model
chat_model = pipeline("conversational", model="microsoft/DialoGPT-medium")

# Define the user input
user_input = "your prompt here"

# Generate a response
try:
    response = chat_model(user_input)
    print(response[0]['generated_text'])
except Exception as e:
    print(f"Error during chat call: {e}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-ed1c59a63f84> in <cell line: 0>()
#       2
#       3 # Load a pre-trained chat model
# ----> 4 chat_model = pipeline("conversational", model="microsoft/DialoGPT-medium")
#       5
#       6 # Define the user input
#
# ...

# %%
from transformers import pipeline

# Load a pre-trained chat model - use 'text-generation' as the task
chat_model = pipeline("text-generation", model="microsoft/DialoGPT-medium")

# Define the user input
# Out:
# pytorch_model.bin:   0%|          | 0.00/863M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/863M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# your prompt here is a bit too vague.

# %%
user_input = "hello"

# Generate a response
print(response)
# Out:
# [{'generated_text': 'how are you?'}]

# %%
from mistralai import Mistral

# Create an instance of the Mistral class
try:
    mistral = Mistral()
except Exception as e:
    print(f"Failed to create Mistral instance: {e}")
    exit(1)

# Define the user role as a string
user_role = "user"

# Call the chat method with the appropriate parameters
try:
    response = mistral.chat(
        model="Mistral-7B-Instruct",
        messages=[
            {"role": user_role, "content": "your prompt here"}
        ]
    )
    print(response)
except Exception as e:
    print(f"Error during chat call: {e}")
# Out:
# Error during chat call: 'Chat' object is not callable
